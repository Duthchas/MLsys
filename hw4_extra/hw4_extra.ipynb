# %% [markdown]
# # 10-714 Homework 4 Extension

# %% [markdown]
# This homework is an extension of homework 4, where you will be implementing the Transformer architecture. For this assignment, all the things you need to implement is in the file `python/needle/nn/nn_transformer.py`. Other things in the needle library remains the same. This homework extension is built on homework 4, so make sure to copy the solutions from homework 4.

# %%
from google.colab import userdata
import os

# 从 Secrets 读取 Token
token = userdata.get('GITHUB_TOKEN')
username = "cyma2882"
repo_name = "Awesome-DLsys"

# %%
# Code to set up the assignment
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/
# !mkdir -p 10714
# %cd /content/drive/MyDrive/10714
# !git clone https://{token}@github.com/{username}/{repo_name}.git
# %cd /content/drive/MyDrive/10714/Awesome-DLsys

# !pip3 install --upgrade --no-deps git+https://github.com/dlsys10714/mugrade.git
# !pip3 install pybind11
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive
# /content/drive/MyDrive/10714
# fatal: destination path 'Awesome-DLsys' already exists and is not an empty directory.
# /content/drive/MyDrive/10714/Awesome-DLsys
# Collecting git+https://github.com/dlsys10714/mugrade.git
#   Cloning https://github.com/dlsys10714/mugrade.git to /tmp/pip-req-build-njhjv_03
#   Running command git clone --filter=blob:none --quiet https://github.com/dlsys10714/mugrade.git /tmp/pip-req-build-njhjv_03
#   Resolved https://github.com/dlsys10714/mugrade.git to commit ac73f725eb2ce0e2c6a38fa540035ee970b8b873
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.12/dist-packages (3.0.1)

# %%
# REQUIRED FOR MUGRADE
MY_API_KEY = "<FILL YOUR API KEY HERE>"

# %%
# !make
# Out:
# CMake Deprecation Warning at CMakeLists.txt:1 (cmake_minimum_required):
#   Compatibility with CMake < 3.10 will be removed from a future version of
#   CMake.
#
#   Update the VERSION argument <min> value.  Or, use the <min>...<max> syntax
#   to tell CMake that the project requires at least <min> but has been updated
#   to work with policies introduced by <max> or earlier.
#
#
# -- Performing Test HAS_FLTO
# -- Performing Test HAS_FLTO - Success
# -- Found pybind11: /usr/local/lib/python3.12/dist-packages/pybind11/include (found version "2.13.6")
# -- Found cuda, building cuda backend
# Thu Nov 27 22:26:11 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# -- Autodetected CUDA architecture(s):  7.5
# -- Configuring done (2.3s)
# -- Generating done (0.9s)
# -- Build files have been written to: /content/drive/MyDrive/10714/hw4_extra/build
# make[1]: Entering directory '/content/drive/MyDrive/10714/hw4_extra/build'
# make[2]: Entering directory '/content/drive/MyDrive/10714/hw4_extra/build'
# make[3]: Entering directory '/content/drive/MyDrive/10714/hw4_extra/build'
# make[3]: Leaving directory '/content/drive/MyDrive/10714/hw4_extra/build'
# make[3]: Entering directory '/content/drive/MyDrive/10714/hw4_extra/build'
# [-25%] Building CXX object CMakeFiles/ndarray_backend_cpu.dir/src/ndarray_backend_cpu.cc.o
# [  0%] Linking CXX shared module /content/drive/MyDrive/10714/hw4_extra/python/needle/backend_ndarray/ndarray_backend_cpu.cpython-312-x86_64-linux-gnu.so
# make[3]: Leaving directory '/content/drive/MyDrive/10714/hw4_extra/build'
# [  0%] Built target ndarray_backend_cpu
# make[3]: Entering directory '/content/drive/MyDrive/10714/hw4_extra/build'
# [ 25%] Building NVCC (Device) object CMakeFiles/ndarray_backend_cuda.dir/src/ndarray_backend_cuda_generated_ndarray_backend_cuda.cu.o

# %%
# %set_env PYTHONPATH ./python
# %set_env NEEDLE_BACKEND nd
# Out:
# env: PYTHONPATH=./python
# env: NEEDLE_BACKEND=nd

# %%
import sys
sys.path.append('./python')

# %%
# Download the PTB dataset

import urllib.request
import os

# !mkdir -p './data/ptb'
# Download Penn Treebank dataset
ptb_data = "https://raw.githubusercontent.com/wojzaremba/lstm/master/data/ptb."
for f in ['train.txt', 'test.txt', 'valid.txt']:
    if not os.path.exists(os.path.join('./data/ptb', f)):
        urllib.request.urlretrieve(ptb_data + f, os.path.join('./data/ptb', f))

# %% [markdown]
# ## Transformers

# %% [markdown]
# In the previous homework you have implemented two sequence models, the Recurrent Neural Network, and Long Short-Term Memory. These models were once the state-of-the-art and default architecture choices on sequence modelling tasks, including language generation, until recently when the famous paper "[Attention Is All You Need](https://arxiv.org/abs/1706.03762)" (Vaswani et al. 2017) came out in 2017. Since then, Transformers, a model architecture introduced in the aforementioned paper, have become the standard and most performant class of model on language tasks.
#
# You will be implementing a Transformer in `python/needle/nn/nn_transformer.py`.
#
# Transformers are composed of three mains components that you will implement.
# 1. A masked multi-head attention mechanism that adaptively focuses on different timesteps of a sequence.
# 2. A residual block consisting of the attention layer followed by a two-layer neural network applied independently at each timestep.
# 3. A Transformer model consisting of several stacked residual blocks (in this homework you will implement a decoder-only transformer).
#
# ![model](https://miro.medium.com/v2/1*ZCFSvkKtppgew3cc7BIaug.png)
#
# The above is a photo of the Transformer architecture from Vaswani et al. 2017. The version of the transformer you will implement is nearly identical, but has layer normalization applied at the start of each residual block (referred to as a [prenorm variant](https://arxiv.org/abs/2002.04745) of the Transformer).

# %% [markdown]
# ## Part 1: Implementing the Multi-Head Attention Activation Layer
#
# In this subproblem, you will be implementing the `forward` function of a "base" attention activation layer `MultiHeadAttention` in `python/needle/nn/nn_transformer.py`. This activation layer will take in three inputs:
# <p style="text-align: center;">multi-head queries $Q \in R^\mathcal{B \times H \times T \times D}$, keys $K \in R^\mathcal{B \times H \times T \times D}$, and values $V \in R^\mathcal{B \times H \times T \times D}$</p>
#
# where $B$ is the batch size, $H$ is the number of attention heads, $T$ is the sequence length, and $D$ is the hidden dimension.
#
# The attention output $X \in R^{B \times H \times T \times D}$ is computed as follows:
#
# <p style="text-align: center;">$X = \text{softmax}(\frac{Q K^T}{\sqrt{D}}) V$</p>
#
# Note that the matrix multiplications above are batched. This functionality is not natively supported in needle yet, so we have provided a convenient function `matmul` for batched matrix multiplications in `MultiHeadAttention`. Your goal in this section is to return $X$ given the input queries, keys, and values.
#
# For auto-regressive Transformer, this attention should support causal masking using the function `self.create_causal_mask` we have provided. This is to make sure that the prediction of next token only depends on it's previous tokens. Specifically, causal masking is applying a mask before the softmax so that the softmax probability is computed over a masked matrix of $\frac{Q K^T}{\sqrt{D}}$.
#
# In addition, your implementation should apply dropout to the attention softmax $\text{softmax}(\frac{Q K^T}{\sqrt{D}})$. You can use the `self.dropout` function of the `MultiHeadAttention` module.
#
# Importantly, this layer is only an activation function, and has no trainable variables (these come later).
#
# Once you have finished your implementation, test your code with the following test cases.

# %%
# !python3 -m pytest -l -v -k "attention_activation"
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/drive/MyDrive/10714/hw4_extra
# plugins: typeguard-4.4.4, anyio-4.11.0, langsmith-0.4.45
# collected 122 items / 106 deselected / 16 selected
#
# tests/hw4_extra/test_transformer.py::test_attention_activation[cpu-0.0-False-64-31-5-4] PASSED [  6%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cpu-0.0-False-64-31-5-8] PASSED [ 12%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cpu-0.0-True-64-31-5-4] PASSED [ 18%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cpu-0.0-True-64-31-5-8] PASSED [ 25%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cpu-0.1-False-64-31-5-4] PASSED [ 31%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cpu-0.1-False-64-31-5-8] PASSED [ 37%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cpu-0.1-True-64-31-5-4] PASSED [ 43%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cpu-0.1-True-64-31-5-8] PASSED [ 50%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cuda-0.0-False-64-31-5-4] PASSED [ 56%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cuda-0.0-False-64-31-5-8] PASSED [ 62%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cuda-0.0-True-64-31-5-4] PASSED [ 68%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cuda-0.0-True-64-31-5-8] PASSED [ 75%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cuda-0.1-False-64-31-5-4] PASSED [ 81%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cuda-0.1-False-64-31-5-8] PASSED [ 87%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cuda-0.1-True-64-31-5-4] PASSED [ 93%]
# tests/hw4_extra/test_transformer.py::test_attention_activation[cuda-0.1-True-64-31-5-8] PASSED [100%]
#
# ===================== 16 passed, 106 deselected in 34.68s ======================

# %%
# !python3 -m mugrade submit "$MY_API_KEY" "hw4extra" -k "attention_activation"

# %% [markdown]
# ## Part 2 Implementing the Self-Attention Layer with trainable parameters
#
# In this subproblem, you will use the `MultiHeadAttention` class you just implemented, and wrap it in a subclass of `Module` called `AttentionLayer` in `python/needle/nn/nn_transformer.py`.
#
# This layer implements the self-attention with prenorm (when k, and v are None in the `self.forward` call) and cross-attention (when k and v are present in the `self.forward` call). We have provided skeleton code with the appropriate layer attributes defined. Your job is to write the forward pass of the `AttentionLayer`. Note that you are implementing multi-head attention, where the number of attention heads is given by the `self.num_head` attribute of the `AttentionLayer` class.
#
# Given inputs $Q \in R^\mathcal{B \times T \times D'}$, keys $K \in R^\mathcal{B \times T \times D'}$, and values $V \in R^\mathcal{B \times T \times D'}$ where $B$ is the batch size, $T$ is the sequence length, and $D'$ is the embedding dimension. This layer performs the following computation sequentially:
#
# (1) map queries, key, and values to heads.
#
# <p style="text-align: center;">$Q' = \text{LayerNorm}_q (Q) \; W_q$</p>
#
# <p style="text-align: center;">$K' = \text{LayerNorm}_k (K) \; W_k$</p>
#
# <p style="text-align: center;">$V' = \text{LayerNorm}_v (V) \; W_v$</p>
#
# where $\text{LayerNorm}_q , \text{LayerNorm}_k, \text{LayerNorm}_v $ are the prenorm `self.prenorm_q`, `self.prenorm_k` and `self.prenorm_v` respectively.
#
# (2) unravel heads from the channels axis.
#
# <p style="text-align: center;">$Q' \in R^{B \times T \times (HD)} \to Q' \in R^{B \times H \times T \times D} $</p>
#
# <p style="text-align: center;">$K' \in R^{B \times T \times (HD)} \to K' \in R^{B \times H \times T \times D} $</p>
#
# <p style="text-align: center;">$V' \in R^{B \times T \times (HD)} \to V' \in R^{B \times H \times T \times D} $</p>
#
# where $H$ and $D$ are `self.num_head` and `self.head_dim` respectively.
#
# (3) compute the multi-head attention activation.
#
# <p style="text-align: center;">$X = \text{softmax}(\frac{Q' (K')^T}{\sqrt{D}}) V'$</p>
#
# <p style="text-align: center;">$X \in R^{B \times H \times T \times D} \to X \in R^{B \times T \times H \times D} $</p>
#
# <p style="text-align: center;">$X \in R^{B \times T \times H \times D} \to X \in R^{B \times T \times (HD)}$</p>
#
# The last two steps do a transpose and then reshape to get the hidden states to be the correct shape.
#
# (4) project back to the input space of the layer with `self.out_projection`
#
# <p style="text-align: center;">$X' = X \; W_o$</p>
#
# Your goal in this part is to return $X$ in the `self.forward` call of `AttentionLayer`. For debugging, you may capture the `probs` variable returned by the inner `MultiHeadAttention` module and store it in an attribute such as `self.probs` of the attention layer.
#
# Once finished, you may test your layer with the following test cases.

# %%
# !python3 -m pytest -l -v -k "attention_layer"

# %%
# !python3 -m mugrade submit "$MY_API_KEY" "hw4extra" -k "attention_layer"

# %% [markdown]
# ## Part 3 Implementing a prenorm residual Transformer Layer
#
# You now have all the parts necessary to build a full Transformer by this point. In this subproblem, you will assemble the attention layer with a feedforward network into a stackable residual block. We have provided starter code in the `TransformerLayer` class.
#
# You will need to define the necessary class attributes in the `self.__init__` call of the module `TransformerLayer`, and fill in the forward pass in `self.forward`. Your transformer layer should support dropout applied to $X'$ from the previous step before adding a residual connection. Implement the following pseudocode of the layer, properly handling the intermediate tensor shapes:
#
# x - current sequence of hidden states
#
# <p style="text-align: center;">$x = x + \text{Dropout}(\text{Attention}(x))$</p>
# <p style="text-align: center;">$x = x + \text{Dropout}(\text{Linear}_{2}(\text{Dropout}(\text{ReLU}(\text{Linear}_{1}(\text{LayerNorm1d}(x))))))$</p>
#
# For the MLP, there are two Linear layers $\text{Linear}_{1}$ and $\text{Linear}_{2}$:
# - $\text{Linear}_{1}$: input shape `q_features`, output shape `hidden_size`
# - $\text{Linear}_{2}$: input shape `hidden_size`, output shape `q_features`
#
# Once finished, run the following test cases.

# %%
# !python3 -m pytest -l -v -k "transformer_layer"

# %%
# !python3 -m mugrade submit "$MY_API_KEY" "hw4extra" -k "transformer_layer"

# %% [markdown]
# ## Part 4 Implementing the Transformer model
#
# In this subsection, you will compose the residual transformer layers you implemented in the previous part to build the full Transformer model. Fill in the code in the `Transformer` class by defining a set of `num_layers` `TransformerLayer` modules with the appropriat parameters passed in from the parent `Transformer` class. Then, implement the `self.forward` call of the `Transformer`.
#
# As is, your current Transformer layers are permutation-invariant, and cannot tell which position each token is in the sequence. To break this symmetry, you will add a positional embedding to your Transformer.
#
# The original Transformer paper uses sinusoidal positional embeddings, and then adds to the input embeddings before the first `TransformerLayer`. These work well, but a more common strategy in modern Transformers is to learn the positional embeddings.
#
# To do this, you should use `needle.nn.Embedding`. In your Transformer implementation, create a learnable positional encoding using `needle.nn.Embedding` from homework 4, with `num_embeddings` set as `sequence_len`. Given an input sequence, you should create a tensor that has the timestep id of each token in the sequence (timesteps have increasing value, representing the position of a token in time), and use it like a word id.
#
# Last, add the created positional encoding to the input token embeddings before your transformer layers.
#
# Once complete, submit the following test cases.

# %%
# !python3 -m pytest -l -v -k "transformer_model"

# %%
# !python3 -m pytest -l -v -k "rmsnorm"
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/drive/MyDrive/10714/hw4_extra
# plugins: typeguard-4.4.4, anyio-4.11.0, langsmith-0.4.45
# collected 122 items / 120 deselected / 2 selected
#
# tests/hw4_extra/test_llama.py::test_rmsnorm[cpu] PASSED                  [ 50%]
# tests/hw4_extra/test_llama.py::test_rmsnorm[cuda] PASSED                 [100%]
#
# ====================== 2 passed, 120 deselected in 2.13s =======================

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python3 -m mugrade submit "$MY_API_KEY" "hw4extra" -k "transformer_model"

# %% [markdown]
# Now, you can train a Transformer language model on the Penn Treebank dataset:
#
# Note: make sure to initialize a transformer model in the class `LanguageModel` of `apps/models.py`; also for Transformers, the final linear head `self.linear` should take in input dimension `embedding_size`.

# %%
import needle as ndl
sys.path.append('./apps')
from models import LanguageModel
from simple_ml import train_ptb, evaluate_ptb

device = ndl.cuda()
corpus = ndl.data.Corpus("data/ptb")
train_data = ndl.data.batchify(corpus.train, batch_size=256, device=device, dtype="float32")
model = LanguageModel(20, len(corpus.dictionary), hidden_size=32, num_layers=1, seq_model='transformer', seq_len=20, device=device)
train_ptb(model, train_data, seq_len=20, n_epochs=10, device=device, lr=0.003, optimizer=ndl.optim.Adam)
evaluate_ptb(model, train_data, seq_len=20, device=device)

# %%
# !python3 -m pytest -l -v -k "test_rope"
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/drive/MyDrive/10714/hw4_extra
# plugins: typeguard-4.4.4, anyio-4.11.0, langsmith-0.4.45
# collected 122 items / 120 deselected / 2 selected
#
# tests/hw4_extra/test_llama.py::test_rope[cpu] PASSED                     [ 50%]
# tests/hw4_extra/test_llama.py::test_rope[cuda] PASSED                    [100%]
#
# ====================== 2 passed, 120 deselected in 2.20s =======================

# %%
# !python3 -m pytest -l -v -k "test_llama_attention"
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/drive/MyDrive/10714/hw4_extra
# plugins: typeguard-4.4.4, anyio-4.11.0, langsmith-0.4.45
# collected 122 items / 120 deselected / 2 selected
#
# tests/hw4_extra/test_llama.py::test_llama_attention[cpu] FAILED          [ 50%]
# tests/hw4_extra/test_llama.py::test_llama_attention[cuda] FAILED         [100%]
#
# =================================== FAILURES ===================================
# __________________________ test_llama_attention[cpu] ___________________________
#
# device = cpu()
#
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_llama_attention(device):
#         dim = 64
#         num_head = 4
#         dim_head = 16
#         seq = 10
#         batch = 2
#
#         layer = nn.LlamaAttention(dim, num_head, dim_head, device=device)
#         x_np = np.random.randn(batch, seq, dim).astype(np.float32)
#         x = ndl.Tensor(x_np, device=device)
#
#         # Create dummy cos/sin
#         cos_np = np.random.randn(seq, dim_head).astype(np.float32)
#         sin_np = np.random.randn(seq, dim_head).astype(np.float32)
#         cos = ndl.Tensor(cos_np, device=device)
#         sin = ndl.Tensor(sin_np, device=device)
#
# >       out = layer(x, cos, sin)
#               ^^^^^^^^^^^^^^^^^^
#
# batch      = 2
# cos        = needle.Tensor([[-0.3105675   0.5474398   1.3977726  -0.31164685 -0.94298416 -2.170393
#    1.4016315   0.350888    1.038...858529  -0.04860868 -1.8026285   0.3573578  -1.5588336   1.0656914
#    0.03979566 -0.51044595 -0.10293898 -0.6047302 ]])
# cos_np     = array([[-0.3105675 ,  0.5474398 ,  1.3977726 , -0.31164685, -0.94298416,
#         -2.170393  ,  1.4016315 ,  0.350888  ...573578 ,
#         -1.5588336 ,  1.0656914 ,  0.03979566, -0.51044595, -0.10293898,
#         -0.6047302 ]], dtype=float32)
# device     = cpu()
# dim        = 64
# dim_head   = 16
# layer      = <needle.nn.nn_transformer.LlamaAttention object at 0x7b25c833e900>
# num_head   = 4
# seq        = 10
# sin        = needle.Tensor([[ 6.93591595e-01 -1.48085281e-01 -1.70040703e+00 -1.08944762e+00
#    1.93136498e-01  3.07241470e-01  7.2...00  9.50342000e-01  6.61914825e-01 -6.42794669e-01
#   -5.75068116e-01  4.85710591e-01 -5.21790087e-01 -8.47937524e-01]])
# sin_np     = array([[ 6.93591595e-01, -1.48085281e-01, -1.70040703e+00,
#         -1.08944762e+00,  1.93136498e-01,  3.07241470e-01,
# ..., -6.42794669e-01,
#         -5.75068116e-01,  4.85710591e-01, -5.21790087e-01,
#         -8.47937524e-01]], dtype=float32)
# x          = needle.Tensor([[[-0.16898292  0.8013502  -0.30072564 ... -1.3258657  -0.19204362
#     0.39644134]
#   [ 1.5662267  -0.085...6039305 -0.9302378
#    -0.11543717]
#   [-0.9259098   2.2443419  -0.41488338 ...  0.95252216 -1.0345143
#    -0.4614549 ]]])
# x_np       = array([[[-0.16898292,  0.8013502 , -0.30072564, ..., -1.3258657 ,
#          -0.19204362,  0.39644134],
#         [ 1.5662...
#         [-0.9259098 ,  2.2443419 , -0.41488338, ...,  0.95252216,
#          -1.0345143 , -0.4614549 ]]], dtype=float32)
#
# tests/hw4_extra/test_llama.py:77:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_basic.py:74: in __call__
#     return self.forward(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         args       = (needle.Tensor([[[-0.16898292  0.8013502  -0.30072564 ... -1.3258657  -0.19204362
#     0.39644134]
#   [ 1.5662267  -0.08...0  9.50342000e-01  6.61914825e-01 -6.42794669e-01
#   -5.75068116e-01  4.85710591e-01 -5.21790087e-01 -8.47937524e-01]]))
#         kwargs     = {}
#         self       = <needle.nn.nn_transformer.LlamaAttention object at 0x7b25c833e900>
# python/needle/nn/nn_transformer.py:529: in forward
#     q = self.q_proj(x)
#         ^^^^^^^^^^^^^^
#         batch      = 2
#         cos        = needle.Tensor([[-0.3105675   0.5474398   1.3977726  -0.31164685 -0.94298416 -2.170393
#    1.4016315   0.350888    1.038...858529  -0.04860868 -1.8026285   0.3573578  -1.5588336   1.0656914
#    0.03979566 -0.51044595 -0.10293898 -0.6047302 ]])
#         dim        = 64
#         self       = <needle.nn.nn_transformer.LlamaAttention object at 0x7b25c833e900>
#         seq_len    = 10
#         sin        = needle.Tensor([[ 6.93591595e-01 -1.48085281e-01 -1.70040703e+00 -1.08944762e+00
#    1.93136498e-01  3.07241470e-01  7.2...00  9.50342000e-01  6.61914825e-01 -6.42794669e-01
#   -5.75068116e-01  4.85710591e-01 -5.21790087e-01 -8.47937524e-01]])
#         x          = needle.Tensor([[[-0.16898292  0.8013502  -0.30072564 ... -1.3258657  -0.19204362
#     0.39644134]
#   [ 1.5662267  -0.085...6039305 -0.9302378
#    -0.11543717]
#   [-0.9259098   2.2443419  -0.41488338 ...  0.95252216 -1.0345143
#    -0.4614549 ]]])
# python/needle/nn/nn_basic.py:74: in __call__
#     return self.forward(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         args       = (needle.Tensor([[[-0.16898292  0.8013502  -0.30072564 ... -1.3258657  -0.19204362
#     0.39644134]
#   [ 1.5662267  -0.08...39305 -0.9302378
#    -0.11543717]
#   [-0.9259098   2.2443419  -0.41488338 ...  0.95252216 -1.0345143
#    -0.4614549 ]]]),)
#         kwargs     = {}
#         self       = <needle.nn.nn_basic.Linear object at 0x7b24d5190bf0>
# python/needle/nn/nn_basic.py:105: in forward
#     Y = ops.matmul(X, self.weight)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         X          = needle.Tensor([[[-0.16898292  0.8013502  -0.30072564 ... -1.3258657  -0.19204362
#     0.39644134]
#   [ 1.5662267  -0.085...6039305 -0.9302378
#    -0.11543717]
#   [-0.9259098   2.2443419  -0.41488338 ...  0.95252216 -1.0345143
#    -0.4614549 ]]])
#         self       = <needle.nn.nn_basic.Linear object at 0x7b24d5190bf0>
# python/needle/ops/ops_mathematic.py:322: in matmul
#     return MatMul()(a, b)
#            ^^^^^^^^^^^^^^
#         a          = needle.Tensor([[[-0.16898292  0.8013502  -0.30072564 ... -1.3258657  -0.19204362
#     0.39644134]
#   [ 1.5662267  -0.085...6039305 -0.9302378
#    -0.11543717]
#   [-0.9259098   2.2443419  -0.41488338 ...  0.95252216 -1.0345143
#    -0.4614549 ]]])
#         b          = needle.Tensor([[ 0.03110722  0.127464   -0.12804419 ...  0.10296112 -0.09807226
#    0.04457694]
#  [-0.1066709  -0.033591....1107121   0.19688454
#    0.09059039]
#  [ 0.2356483   0.14962399 -0.2558929  ...  0.10992271 -0.06290345
#    0.09946269]])
# python/needle/autograd.py:80: in __call__
#     return Tensor.make_from_op(self, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         args       = (needle.Tensor([[[-0.16898292  0.8013502  -0.30072564 ... -1.3258657  -0.19204362
#     0.39644134]
#   [ 1.5662267  -0.08...1107121   0.19688454
#    0.09059039]
#  [ 0.2356483   0.14962399 -0.2558929  ...  0.10992271 -0.06290345
#    0.09946269]]))
#         self       = <needle.ops.ops_mathematic.MatMul object at 0x7b25c626b890>
# python/needle/autograd.py:242: in make_from_op
#     tensor.realize_cached_data()
#         inputs     = (needle.Tensor([[[-0.16898292  0.8013502  -0.30072564 ... -1.3258657  -0.19204362
#     0.39644134]
#   [ 1.5662267  -0.08...1107121   0.19688454
#    0.09059039]
#  [ 0.2356483   0.14962399 -0.2558929  ...  0.10992271 -0.06290345
#    0.09946269]]))
#         op         = <needle.ops.ops_mathematic.MatMul object at 0x7b25c626b890>
#         tensor     = <[AssertionError() raised in repr()] Tensor object at 0x7b25c626b920>
# python/needle/autograd.py:107: in realize_cached_data
#     self.cached_data = self.op.compute(
#         self       = <[AssertionError() raised in repr()] Tensor object at 0x7b25c626b920>
# python/needle/ops/ops_mathematic.py:295: in compute
#     return array_api.matmul(a, b)
#            ^^^^^^^^^^^^^^^^^^^^^^
#         a          = NDArray([[[-0.16898292  0.8013502  -0.30072564 ... -1.3258657  -0.19204362
#     0.39644134]
#   [ 1.5662267  -0.08532185 ...2378
#    -0.11543717]
#   [-0.9259098   2.2443419  -0.41488338 ...  0.95252216 -1.0345143
#    -0.4614549 ]]], device=cpu())
#         b          = NDArray([[ 0.03110722  0.127464   -0.12804419 ...  0.10296112 -0.09807226
#    0.04457694]
#  [-0.1066709  -0.03359166 -0....9688454
#    0.09059039]
#  [ 0.2356483   0.14962399 -0.2558929  ...  0.10992271 -0.06290345
#    0.09946269]], device=cpu())
#         self       = <needle.ops.ops_mathematic.MatMul object at 0x7b25c626b890>
# python/needle/backend_ndarray/ndarray.py:822: in matmul
#     return a @ b
#            ^^^^^
#         a          = NDArray([[[-0.16898292  0.8013502  -0.30072564 ... -1.3258657  -0.19204362
#     0.39644134]
#   [ 1.5662267  -0.08532185 ...2378
#    -0.11543717]
#   [-0.9259098   2.2443419  -0.41488338 ...  0.95252216 -1.0345143
#    -0.4614549 ]]], device=cpu())
#         b          = NDArray([[ 0.03110722  0.127464   -0.12804419 ...  0.10296112 -0.09807226
#    0.04457694]
#  [-0.1066709  -0.03359166 -0....9688454
#    0.09059039]
#  [ 0.2356483   0.14962399 -0.2558929  ...  0.10992271 -0.06290345
#    0.09946269]], device=cpu())
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = NDArray([[[-0.16898292  0.8013502  -0.30072564 ... -1.3258657  -0.19204362
#     0.39644134]
#   [ 1.5662267  -0.08532185 ...2378
#    -0.11543717]
#   [-0.9259098   2.2443419  -0.41488338 ...  0.95252216 -1.0345143
#    -0.4614549 ]]], device=cpu())
# other = NDArray([[ 0.03110722  0.127464   -0.12804419 ...  0.10296112 -0.09807226
#    0.04457694]
#  [-0.1066709  -0.03359166 -0....9688454
#    0.09059039]
#  [ 0.2356483   0.14962399 -0.2558929  ...  0.10992271 -0.06290345
#    0.09946269]], device=cpu())
#
#     def __matmul__(self, other: "NDArray") -> "NDArray":
#         """Matrix multplication of two arrays.  This requires that both arrays
#         be 2D (i.e., we don't handle batch matrix multiplication), and that the
#         sizes match up properly for matrix multiplication.
#
#         In the case of the CPU backend, you will implement an efficient "tiled"
#         version of matrix multiplication for the case when all dimensions of
#         the array are divisible by self.device.__tile_size__.  In this case,
#         the code below will restride and compact the matrix into tiled form,
#         and then pass to the relevant CPU backend.  For the CPU version we will
#         just fall back to the naive CPU implementation if the array shape is not
#         a multiple of the tile size
#
#         The GPU (and numpy) versions don't have any tiled version (or rather,
#         the GPU version will just work natively by tiling any input size).
#         """
#
# >       assert self.ndim == 2 and other.ndim == 2
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       AssertionError
#
# other      = NDArray([[ 0.03110722  0.127464   -0.12804419 ...  0.10296112 -0.09807226
#    0.04457694]
#  [-0.1066709  -0.03359166 -0....9688454
#    0.09059039]
#  [ 0.2356483   0.14962399 -0.2558929  ...  0.10992271 -0.06290345
#    0.09946269]], device=cpu())
# self       = NDArray([[[-0.16898292  0.8013502  -0.30072564 ... -1.3258657  -0.19204362
#     0.39644134]
#   [ 1.5662267  -0.08532185 ...2378
#    -0.11543717]
#   [-0.9259098   2.2443419  -0.41488338 ...  0.95252216 -1.0345143
#    -0.4614549 ]]], device=cpu())
#
# python/needle/backend_ndarray/ndarray.py:589: AssertionError
# __________________________ test_llama_attention[cuda] __________________________
#
# device = cuda()
#
#     @pytest.mark.parametrize("device", _DEVICES, ids=["cpu", "cuda"])
#     def test_llama_attention(device):
#         dim = 64
#         num_head = 4
#         dim_head = 16
#         seq = 10
#         batch = 2
#
#         layer = nn.LlamaAttention(dim, num_head, dim_head, device=device)
#         x_np = np.random.randn(batch, seq, dim).astype(np.float32)
#         x = ndl.Tensor(x_np, device=device)
#
#         # Create dummy cos/sin
#         cos_np = np.random.randn(seq, dim_head).astype(np.float32)
#         sin_np = np.random.randn(seq, dim_head).astype(np.float32)
#         cos = ndl.Tensor(cos_np, device=device)
#         sin = ndl.Tensor(sin_np, device=device)
#
# >       out = layer(x, cos, sin)
#               ^^^^^^^^^^^^^^^^^^
#
# batch      = 2
# cos        = needle.Tensor([[ 0.16438971 -1.4582863   0.7023875  -0.01536746 -0.40425152 -0.28381637
#    0.34127098 -0.23574716  0.6...5512524 -1.3961473  -0.9416566   0.24973734 -1.3745002  -0.6481661
#    0.21035933 -0.58144003  1.5673813  -0.61137587]])
# cos_np     = array([[ 0.16438971, -1.4582863 ,  0.7023875 , -0.01536746, -0.40425152,
#         -0.28381637,  0.34127098, -0.23574716...4973734,
#         -1.3745002 , -0.6481661 ,  0.21035933, -0.58144003,  1.5673813 ,
#         -0.61137587]], dtype=float32)
# device     = cuda()
# dim        = 64
# dim_head   = 16
# layer      = <needle.nn.nn_transformer.LlamaAttention object at 0x7b24d5747aa0>
# num_head   = 4
# seq        = 10
# sin        = needle.Tensor([[-8.35190177e-01 -1.53380120e+00  5.59473813e-01  7.11286142e-02
#   -2.19116043e-02 -1.99166760e-01  1.1...01 -4.72287893e-01  2.12386742e-01  7.20436811e-01
#   -1.39632332e+00  3.67025197e-01  4.70163196e-01  1.39653111e+00]])
# sin_np     = array([[-8.35190177e-01, -1.53380120e+00,  5.59473813e-01,
#          7.11286142e-02, -2.19116043e-02, -1.99166760e-01,
# ...,  7.20436811e-01,
#         -1.39632332e+00,  3.67025197e-01,  4.70163196e-01,
#          1.39653111e+00]], dtype=float32)
# x          = needle.Tensor([[[ 0.5720352   0.16436812 -0.05000991 ... -0.992433   -1.8658165
#    -0.37887955]
#   [ 0.6830882  -1.6280...4723071  0.3874098
#     1.1888835 ]
#   [-0.3616083  -0.13967599  0.6687172  ...  1.1609806  -1.2263113
#     1.8484532 ]]])
# x_np       = array([[[ 0.5720352 ,  0.16436812, -0.05000991, ..., -0.992433  ,
#          -1.8658165 , -0.37887955],
#         [ 0.6830...
#         [-0.3616083 , -0.13967599,  0.6687172 , ...,  1.1609806 ,
#          -1.2263113 ,  1.8484532 ]]], dtype=float32)
#
# tests/hw4_extra/test_llama.py:77:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# python/needle/nn/nn_basic.py:74: in __call__
#     return self.forward(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         args       = (needle.Tensor([[[ 0.5720352   0.16436812 -0.05000991 ... -0.992433   -1.8658165
#    -0.37887955]
#   [ 0.6830882  -1.628...1 -4.72287893e-01  2.12386742e-01  7.20436811e-01
#   -1.39632332e+00  3.67025197e-01  4.70163196e-01  1.39653111e+00]]))
#         kwargs     = {}
#         self       = <needle.nn.nn_transformer.LlamaAttention object at 0x7b24d5747aa0>
# python/needle/nn/nn_transformer.py:529: in forward
#     q = self.q_proj(x)
#         ^^^^^^^^^^^^^^
#         batch      = 2
#         cos        = needle.Tensor([[ 0.16438971 -1.4582863   0.7023875  -0.01536746 -0.40425152 -0.28381637
#    0.34127098 -0.23574716  0.6...5512524 -1.3961473  -0.9416566   0.24973734 -1.3745002  -0.6481661
#    0.21035933 -0.58144003  1.5673813  -0.61137587]])
#         dim        = 64
#         self       = <needle.nn.nn_transformer.LlamaAttention object at 0x7b24d5747aa0>
#         seq_len    = 10
#         sin        = needle.Tensor([[-8.35190177e-01 -1.53380120e+00  5.59473813e-01  7.11286142e-02
#   -2.19116043e-02 -1.99166760e-01  1.1...01 -4.72287893e-01  2.12386742e-01  7.20436811e-01
#   -1.39632332e+00  3.67025197e-01  4.70163196e-01  1.39653111e+00]])
#         x          = needle.Tensor([[[ 0.5720352   0.16436812 -0.05000991 ... -0.992433   -1.8658165
#    -0.37887955]
#   [ 0.6830882  -1.6280...4723071  0.3874098
#     1.1888835 ]
#   [-0.3616083  -0.13967599  0.6687172  ...  1.1609806  -1.2263113
#     1.8484532 ]]])
# python/needle/nn/nn_basic.py:74: in __call__
#     return self.forward(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         args       = (needle.Tensor([[[ 0.5720352   0.16436812 -0.05000991 ... -0.992433   -1.8658165
#    -0.37887955]
#   [ 0.6830882  -1.628...23071  0.3874098
#     1.1888835 ]
#   [-0.3616083  -0.13967599  0.6687172  ...  1.1609806  -1.2263113
#     1.8484532 ]]]),)
#         kwargs     = {}
#         self       = <needle.nn.nn_basic.Linear object at 0x7b24d51b39e0>
# python/needle/nn/nn_basic.py:105: in forward
#     Y = ops.matmul(X, self.weight)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#         X          = needle.Tensor([[[ 0.5720352   0.16436812 -0.05000991 ... -0.992433   -1.8658165
#    -0.37887955]
#   [ 0.6830882  -1.6280...4723071  0.3874098
#     1.1888835 ]
#   [-0.3616083  -0.13967599  0.6687172  ...  1.1609806  -1.2263113
#     1.8484532 ]]])
#         self       = <needle.nn.nn_basic.Linear object at 0x7b24d51b39e0>
# python/needle/ops/ops_mathematic.py:322: in matmul
#     return MatMul()(a, b)
#            ^^^^^^^^^^^^^^
#         a          = needle.Tensor([[[ 0.5720352   0.16436812 -0.05000991 ... -0.992433   -1.8658165
#    -0.37887955]
#   [ 0.6830882  -1.6280...4723071  0.3874098
#     1.1888835 ]
#   [-0.3616083  -0.13967599  0.6687172  ...  1.1609806  -1.2263113
#     1.8484532 ]]])
#         b          = needle.Tensor([[-0.19659285  0.10541829 -0.03299537 ...  0.01987749  0.2110034
#   -0.2671389 ]
#  [ 0.08182457  0.0457904....11795768  0.27257648
#    0.20686087]
#  [-0.10637468  0.02125555  0.01924172 ...  0.17306888  0.16914451
#   -0.00500539]])
# python/needle/autograd.py:80: in __call__
#     return Tensor.make_from_op(self, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         args       = (needle.Tensor([[[ 0.5720352   0.16436812 -0.05000991 ... -0.992433   -1.8658165
#    -0.37887955]
#   [ 0.6830882  -1.628...11795768  0.27257648
#    0.20686087]
#  [-0.10637468  0.02125555  0.01924172 ...  0.17306888  0.16914451
#   -0.00500539]]))
#         self       = <needle.ops.ops_mathematic.MatMul object at 0x7b24d51b0a70>
# python/needle/autograd.py:242: in make_from_op
#     tensor.realize_cached_data()
#         inputs     = (needle.Tensor([[[ 0.5720352   0.16436812 -0.05000991 ... -0.992433   -1.8658165
#    -0.37887955]
#   [ 0.6830882  -1.628...11795768  0.27257648
#    0.20686087]
#  [-0.10637468  0.02125555  0.01924172 ...  0.17306888  0.16914451
#   -0.00500539]]))
#         op         = <needle.ops.ops_mathematic.MatMul object at 0x7b24d51b0a70>
#         tensor     = <[AssertionError() raised in repr()] Tensor object at 0x7b24d51b3e30>
# python/needle/autograd.py:107: in realize_cached_data
#     self.cached_data = self.op.compute(
#         self       = <[AssertionError() raised in repr()] Tensor object at 0x7b24d51b3e30>
# python/needle/ops/ops_mathematic.py:295: in compute
#     return array_api.matmul(a, b)
#            ^^^^^^^^^^^^^^^^^^^^^^
#         a          = NDArray([[[ 0.5720352   0.16436812 -0.05000991 ... -0.992433   -1.8658165
#    -0.37887955]
#   [ 0.6830882  -1.6280699  -...098
#     1.1888835 ]
#   [-0.3616083  -0.13967599  0.6687172  ...  1.1609806  -1.2263113
#     1.8484532 ]]], device=cuda())
#         b          = NDArray([[-0.19659285  0.10541829 -0.03299537 ...  0.01987749  0.2110034
#   -0.2671389 ]
#  [ 0.08182457  0.04579046 -0.2...257648
#    0.20686087]
#  [-0.10637468  0.02125555  0.01924172 ...  0.17306888  0.16914451
#   -0.00500539]], device=cuda())
#         self       = <needle.ops.ops_mathematic.MatMul object at 0x7b24d51b0a70>
# python/needle/backend_ndarray/ndarray.py:822: in matmul
#     return a @ b
#            ^^^^^
#         a          = NDArray([[[ 0.5720352   0.16436812 -0.05000991 ... -0.992433   -1.8658165
#    -0.37887955]
#   [ 0.6830882  -1.6280699  -...098
#     1.1888835 ]
#   [-0.3616083  -0.13967599  0.6687172  ...  1.1609806  -1.2263113
#     1.8484532 ]]], device=cuda())
#         b          = NDArray([[-0.19659285  0.10541829 -0.03299537 ...  0.01987749  0.2110034
#   -0.2671389 ]
#  [ 0.08182457  0.04579046 -0.2...257648
#    0.20686087]
#  [-0.10637468  0.02125555  0.01924172 ...  0.17306888  0.16914451
#   -0.00500539]], device=cuda())
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# self = NDArray([[[ 0.5720352   0.16436812 -0.05000991 ... -0.992433   -1.8658165
#    -0.37887955]
#   [ 0.6830882  -1.6280699  -...098
#     1.1888835 ]
#   [-0.3616083  -0.13967599  0.6687172  ...  1.1609806  -1.2263113
#     1.8484532 ]]], device=cuda())
# other = NDArray([[-0.19659285  0.10541829 -0.03299537 ...  0.01987749  0.2110034
#   -0.2671389 ]
#  [ 0.08182457  0.04579046 -0.2...257648
#    0.20686087]
#  [-0.10637468  0.02125555  0.01924172 ...  0.17306888  0.16914451
#   -0.00500539]], device=cuda())
#
#     def __matmul__(self, other: "NDArray") -> "NDArray":
#         """Matrix multplication of two arrays.  This requires that both arrays
#         be 2D (i.e., we don't handle batch matrix multiplication), and that the
#         sizes match up properly for matrix multiplication.
#
#         In the case of the CPU backend, you will implement an efficient "tiled"
#         version of matrix multiplication for the case when all dimensions of
#         the array are divisible by self.device.__tile_size__.  In this case,
#         the code below will restride and compact the matrix into tiled form,
#         and then pass to the relevant CPU backend.  For the CPU version we will
#         just fall back to the naive CPU implementation if the array shape is not
#         a multiple of the tile size
#
#         The GPU (and numpy) versions don't have any tiled version (or rather,
#         the GPU version will just work natively by tiling any input size).
#         """
#
# >       assert self.ndim == 2 and other.ndim == 2
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       AssertionError
#
# other      = NDArray([[-0.19659285  0.10541829 -0.03299537 ...  0.01987749  0.2110034
#   -0.2671389 ]
#  [ 0.08182457  0.04579046 -0.2...257648
#    0.20686087]
#  [-0.10637468  0.02125555  0.01924172 ...  0.17306888  0.16914451
#   -0.00500539]], device=cuda())
# self       = NDArray([[[ 0.5720352   0.16436812 -0.05000991 ... -0.992433   -1.8658165
#    -0.37887955]
#   [ 0.6830882  -1.6280699  -...098
#     1.1888835 ]
#   [-0.3616083  -0.13967599  0.6687172  ...  1.1609806  -1.2263113
#     1.8484532 ]]], device=cuda())
#
# python/needle/backend_ndarray/ndarray.py:589: AssertionError
# =========================== short test summary info ============================
# FAILED tests/hw4_extra/test_llama.py::test_llama_attention[cpu] - AssertionError
# FAILED tests/hw4_extra/test_llama.py::test_llama_attention[cuda] - AssertionError
# ====================== 2 failed, 120 deselected in 2.91s =======================

# %%
# !python3 -m pytest -l -v tests/hw4_extra/test_llama.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/drive/MyDrive/10714/hw4_extra
# plugins: typeguard-4.4.4, anyio-4.11.0, langsmith-0.4.45
# collected 10 items
#
# tests/hw4_extra/test_llama.py::test_rmsnorm[cpu] PASSED                  [ 10%]
# tests/hw4_extra/test_llama.py::test_rmsnorm[cuda] PASSED                 [ 20%]
# tests/hw4_extra/test_llama.py::test_rope[cpu] PASSED                     [ 30%]
# tests/hw4_extra/test_llama.py::test_rope[cuda] PASSED                    [ 40%]
# tests/hw4_extra/test_llama.py::test_llama_attention[cpu] PASSED          [ 50%]
# tests/hw4_extra/test_llama.py::test_llama_attention[cuda] PASSED         [ 60%]
# tests/hw4_extra/test_llama.py::test_llama_feedforward[cpu] PASSED        [ 70%]
# tests/hw4_extra/test_llama.py::test_llama_feedforward[cuda] PASSED       [ 80%]
# tests/hw4_extra/test_llama.py::test_llama2_model[cpu] PASSED             [ 90%]
# tests/hw4_extra/test_llama.py::test_llama2_model[cuda] PASSED            [100%]
#
# ============================== 10 passed in 0.42s ==============================

# %%
# !python3 -m pytest -v tests/hw4_extra/test_llama_comprehensive.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/drive/MyDrive/10714/hw4_extra
# plugins: typeguard-4.4.4, anyio-4.11.0, langsmith-0.4.45
# collected 700 items
#
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-1-1-32] PASSED [  0%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-1-1-64] PASSED [  0%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-1-1-128] PASSED [  0%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-1-2-32] PASSED [  0%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-1-2-64] PASSED [  0%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-1-2-128] PASSED [  0%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-1-4-32] PASSED [  1%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-1-4-64] PASSED [  1%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-1-4-128] PASSED [  1%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-5-1-32] PASSED [  1%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-5-1-64] PASSED [  1%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-5-1-128] PASSED [  1%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-5-2-32] PASSED [  1%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-5-2-64] PASSED [  2%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-5-2-128] PASSED [  2%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-5-4-32] PASSED [  2%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-5-4-64] PASSED [  2%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-5-4-128] PASSED [  2%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-10-1-32] PASSED [  2%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-10-1-64] PASSED [  2%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-10-1-128] PASSED [  3%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-10-2-32] PASSED [  3%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-10-2-64] PASSED [  3%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-10-2-128] PASSED [  3%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-10-4-32] PASSED [  3%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-10-4-64] PASSED [  3%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cpu-10-4-128] PASSED [  3%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-1-1-32] PASSED [  4%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-1-1-64] PASSED [  4%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-1-1-128] PASSED [  4%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-1-2-32] PASSED [  4%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-1-2-64] PASSED [  4%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-1-2-128] PASSED [  4%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-1-4-32] PASSED [  4%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-1-4-64] PASSED [  5%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-1-4-128] PASSED [  5%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-5-1-32] PASSED [  5%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-5-1-64] PASSED [  5%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-5-1-128] PASSED [  5%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-5-2-32] PASSED [  5%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-5-2-64] PASSED [  5%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-5-2-128] PASSED [  6%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-5-4-32] PASSED [  6%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-5-4-64] PASSED [  6%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-5-4-128] PASSED [  6%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-10-1-32] PASSED [  6%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-10-1-64] PASSED [  6%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-10-1-128] PASSED [  6%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-10-2-32] PASSED [  7%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-10-2-64] PASSED [  7%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-10-2-128] PASSED [  7%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-10-4-32] PASSED [  7%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-10-4-64] PASSED [  7%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_shape_and_numerical[cuda-10-4-128] PASSED [  7%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_zero_mean[cpu] PASSED [  7%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rmsnorm_zero_mean[cuda] PASSED [  8%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rope_shape[cpu-2-1-16-1] PASSED [  8%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rope_shape[cpu-2-1-16-5] PASSED [  8%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rope_shape[cpu-2-1-16-10] PASSED [  8%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rope_shape[cpu-2-1-16-32] PASSED [  8%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rope_shape[cpu-2-1-32-1] PASSED [  8%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rope_shape[cpu-2-1-32-5] PASSED [  8%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rope_shape[cpu-2-1-32-10] PASSED [  9%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rope_shape[cpu-2-1-32-32] PASSED [  9%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rope_shape[cpu-2-1-64-1] PASSED [  9%]
# tests/hw4_extra/test_llama_comprehensive.py::test_rope_shape[cpu-2-1
]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-5-4-2-64-64] PASSED [ 62%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-5-4-2-128-32] PASSED [ 62%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-5-4-2-128-64] PASSED [ 62%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-5-4-4-64-32] PASSED [ 63%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-5-4-4-64-64] PASSED [ 63%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-5-4-4-128-32] PASSED [ 63%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-5-4-4-128-64] PASSED [ 63%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-2-1-64-32] PASSED [ 63%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-2-1-64-64] PASSED [ 63%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-2-1-128-32] PASSED [ 63%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-2-1-128-64] PASSED [ 64%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-2-2-64-32] PASSED [ 64%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-2-2-64-64] PASSED [ 64%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-2-2-128-32] PASSED [ 64%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-2-2-128-64] PASSED [ 64%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-2-4-64-32] PASSED [ 64%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-2-4-64-64] PASSED [ 64%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-2-4-128-32] PASSED [ 65%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-2-4-128-64] PASSED [ 65%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-4-1-64-32] PASSED [ 65%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-4-1-64-64] PASSED [ 65%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-4-1-128-32] PASSED [ 65%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-4-1-128-64] PASSED [ 65%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-4-2-64-32] PASSED [ 65%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-4-2-64-64] PASSED [ 66%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-4-2-128-32] PASSED [ 66%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-4-2-128-64] PASSED [ 66%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-4-4-64-32] PASSED [ 66%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-4-4-64-64] PASSED [ 66%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-4-4-128-32] PASSED [ 66%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-1-10-4-4-128-64] PASSED [ 66%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-2-1-2-1-64-32] PASSED [ 67%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-2-1-2-1-64-64] PASSED [ 67%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-2-1-2-1-128-32] PASSED [ 67%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-2-1-2-1-128-64] PASSED [ 67%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cpu-2-1-2-2-64-32] PASSED [ 67%]
# ...
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-2-2-64-64] PASSED [ 78%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-2-2-128-32] PASSED [ 78%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-2-2-128-64] PASSED [ 78%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-2-4-64-32] PASSED [ 78%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-2-4-64-64] PASSED [ 78%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-2-4-128-32] PASSED [ 78%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-2-4-128-64] PASSED [ 78%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-4-1-64-32] PASSED [ 79%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-4-1-64-64] PASSED [ 79%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-4-1-128-32] PASSED [ 79%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-4-1-128-64] PASSED [ 79%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-4-2-64-32] PASSED [ 79%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-4-2-64-64] PASSED [ 79%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-4-2-128-32] PASSED [ 79%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-4-2-128-64] PASSED [ 80%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-4-4-64-32] PASSED [ 80%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-4-4-64-64] PASSED [ 80%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-4-4-128-32] PASSED [ 80%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-1-4-4-128-64] PASSED [ 80%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-2-1-64-32] PASSED [ 80%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-2-1-64-64] PASSED [ 80%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-2-1-128-32] PASSED [ 81%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-2-1-128-64] PASSED [ 81%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-2-2-64-32] PASSED [ 81%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-2-2-64-64] PASSED [ 81%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-2-2-128-32] PASSED [ 81%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-2-2-128-64] PASSED [ 81%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-2-4-64-32] PASSED [ 81%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-2-4-64-64] PASSED [ 82%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-2-4-128-32] PASSED [ 82%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-2-4-128-64] PASSED [ 82%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-4-1-64-32] PASSED [ 82%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-4-1-64-64] PASSED [ 82%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-4-1-128-32] PASSED [ 82%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-4-1-128-64] PASSED [ 82%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-4-2-64-32] PASSED [ 83%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-4-2-64-64] PASSED [ 83%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-4-2-128-32] PASSED [ 83%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-4-2-128-64] PASSED [ 83%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-4-4-64-32] PASSED [ 83%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-4-4-64-64] PASSED [ 83%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-4-4-128-32] PASSED [ 83%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-5-4-4-128-64] PASSED [ 84%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-2-1-64-32] PASSED [ 84%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-2-1-64-64] PASSED [ 84%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-2-1-128-32] PASSED [ 84%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-2-1-128-64] PASSED [ 84%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-2-2-64-32] PASSED [ 84%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-2-2-64-64] PASSED [ 84%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-2-2-128-32] PASSED [ 85%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-2-2-128-64] PASSED [ 85%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-2-4-64-32] PASSED [ 85%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-2-4-64-64] PASSED [ 85%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-2-4-128-32] PASSED [ 85%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-2-4-128-64] PASSED [ 85%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-4-1-64-32] PASSED [ 85%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-4-1-64-64] PASSED [ 86%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-4-1-128-32] PASSED [ 86%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-4-1-128-64] PASSED [ 86%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-4-2-64-32] PASSED [ 86%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-4-2-64-64] PASSED [ 86%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-4-2-128-32] PASSED [ 86%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-4-2-128-64] PASSED [ 86%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-4-4-64-32] PASSED [ 87%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-4-4-64-64] PASSED [ 87%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-4-4-128-32] PASSED [ 87%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-1-10-4-4-128-64] PASSED [ 87%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-2-1-64-32] PASSED [ 87%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-2-1-64-64] PASSED [ 87%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-2-1-128-32] PASSED [ 87%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-2-1-128-64] PASSED [ 88%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-2-2-64-32] PASSED [ 88%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-2-2-64-64] PASSED [ 88%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-2-2-128-32] PASSED [ 88%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-2-2-128-64] PASSED [ 88%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-2-4-64-32] PASSED [ 88%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-2-4-64-64] PASSED [ 88%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-2-4-128-32] PASSED [ 89%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-2-4-128-64] PASSED [ 89%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-4-1-64-32] PASSED [ 89%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-4-1-64-64] PASSED [ 89%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-4-1-128-32] PASSED [ 89%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-4-1-128-64] PASSED [ 89%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-4-2-64-32] PASSED [ 89%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-4-2-64-64] PASSED [ 90%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-4-2-128-32] PASSED [ 90%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-4-2-128-64] PASSED [ 90%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-4-4-64-32] PASSED [ 90%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-4-4-64-64] PASSED [ 90%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-4-4-128-32] PASSED [ 90%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-1-4-4-128-64] PASSED [ 90%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-2-1-64-32] PASSED [ 91%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-2-1-64-64] PASSED [ 91%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-2-1-128-32] PASSED [ 91%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-2-1-128-64] PASSED [ 91%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-2-2-64-32] PASSED [ 91%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-2-2-64-64] PASSED [ 91%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-2-2-128-32] PASSED [ 91%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-2-2-128-64] PASSED [ 92%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-2-4-64-32] PASSED [ 92%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-2-4-64-64] PASSED [ 92%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-2-4-128-32] PASSED [ 92%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-2-4-128-64] PASSED [ 92%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-4-1-64-32] PASSED [ 92%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-4-1-64-64] PASSED [ 92%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-4-1-128-32] PASSED [ 93%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-4-1-128-64] PASSED [ 93%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-4-2-64-32] PASSED [ 93%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-4-2-64-64] PASSED [ 93%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-4-2-128-32] PASSED [ 93%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-4-2-128-64] PASSED [ 93%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-4-4-64-32] PASSED [ 93%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-4-4-64-64] PASSED [ 94%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-4-4-128-32] PASSED [ 94%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-5-4-4-128-64] PASSED [ 94%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-2-1-64-32] PASSED [ 94%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-2-1-64-64] PASSED [ 94%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-2-1-128-32] PASSED [ 94%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-2-1-128-64] PASSED [ 94%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-2-2-64-32] PASSED [ 95%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-2-2-64-64] PASSED [ 95%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-2-2-128-32] PASSED [ 95%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-2-2-128-64] PASSED [ 95%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-2-4-64-32] PASSED [ 95%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-2-4-64-64] PASSED [ 95%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-2-4-128-32] PASSED [ 95%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-2-4-128-64] PASSED [ 96%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-4-1-64-32] PASSED [ 96%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-4-1-64-64] PASSED [ 96%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-4-1-128-32] PASSED [ 96%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-4-1-128-64] PASSED [ 96%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-4-2-64-32] PASSED [ 96%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-4-2-64-64] PASSED [ 96%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-4-2-128-32] PASSED [ 97%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-4-2-128-64] PASSED [ 97%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-4-4-64-32] PASSED [ 97%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-4-4-64-64] PASSED [ 97%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-4-4-128-32] PASSED [ 97%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_shape[cuda-2-10-4-4-128-64] PASSED [ 97%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_no_nan[cpu] PASSED [ 97%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_no_nan[cuda] PASSED [ 98%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_varying_seq_len[cpu] PASSED [ 98%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_varying_seq_len[cuda] PASSED [ 98%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_single_batch[cpu] PASSED [ 98%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_single_batch[cuda] PASSED [ 98%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_single_token[cpu] PASSED [ 98%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama2_model_single_token[cuda] PASSED [ 98%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama_transformer_layer[cpu] PASSED [ 99%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama_transformer_layer[cuda] PASSED [ 99%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama_vs_llama[cpu] PASSED [ 99%]
# tests/hw4_extra/test_llama_comprehensive.py::test_llama_vs_llama[cuda] PASSED [ 99%]
# tests/hw4_extra/test_llama_comprehensive.py::test_very_small_inputs[cpu] PASSED [ 99%]
# tests/hw4_extra/test_llama_comprehensive.py::test_very_small_inputs[cuda] PASSED [ 99%]
# tests/hw4_extra/test_llama_comprehensive.py::test_large_values[cpu] PASSED [ 99%]
# tests/hw4_extra/test_llama_comprehensive.py::test_large_values[cuda] PASSED [100%]
#
# ============================= 700 passed in 5.51s ==============================

# %%
# !python3 generate_llama_reference.py
# Out:
# ============================================================
# 生成 Llama2 参考数据
# ============================================================
# Generating RMSNorm reference...
#   Saved tests/hw4_extra/data/llama/rmsnorm-64-2-10.npy
# Generating RoPE reference...
#   Saved tests/hw4_extra/data/llama/rope_q-10-32-2-4.npy
#   Saved tests/hw4_extra/data/llama/rope_k-10-32-2-4.npy
# Generating LlamaAttention reference...
#   Saved tests/hw4_extra/data/llama/attention_out-64-4-16-2-10.npy
#   Saved tests/hw4_extra/data/llama/attention_weights-64-4-16-2-10.npz
# Generating LlamaFeedForward reference...
#   Saved tests/hw4_extra/data/llama/feedforward_out-64-128-2-10.npy
#   Saved tests/hw4_extra/data/llama/feedforward_weights-64-128-2-10.npz
#
# ============================================================
# 完成！参考数据已保存到 tests/hw4_extra/data/llama/
# ============================================================

# %%
# !python3 -m pytest tests/hw4_extra/test_llama_with_reference.py -v -s
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.12.12, pytest-8.4.2, pluggy-1.6.0 -- /usr/bin/python3
# cachedir: .pytest_cache
# rootdir: /content/drive/MyDrive/10714/hw4_extra
# plugins: typeguard-4.4.4, anyio-4.11.0, langsmith-0.4.47
# collecting ... Using needle backend
# collected 8 items
#
# tests/hw4_extra/test_llama_with_reference.py::test_rmsnorm_vs_pytorch[cpu] PASSED
# tests/hw4_extra/test_llama_with_reference.py::test_rmsnorm_vs_pytorch[cuda] PASSED
# tests/hw4_extra/test_llama_with_reference.py::test_rope_vs_pytorch[cpu] PASSED
# tests/hw4_extra/test_llama_with_reference.py::test_rope_vs_pytorch[cuda] PASSED
# tests/hw4_extra/test_llama_with_reference.py::test_llama_attention_vs_pytorch[cpu] PASSED
# tests/hw4_extra/test_llama_with_reference.py::test_llama_attention_vs_pytorch[cuda] PASSED
# tests/hw4_extra/test_llama_with_reference.py::test_llama_feedforward_vs_pytorch[cpu] PASSED
# tests/hw4_extra/test_llama_with_reference.py::test_llama_feedforward_vs_pytorch[cuda] PASSED
#
# ============================== 8 passed in 0.56s ===============================
